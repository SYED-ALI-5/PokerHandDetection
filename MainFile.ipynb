# %% [markdown]
# # Imports

# %%
from ultralytics import YOLO
import cv2
import cvzone
import math
import HelperFunction

# %% [markdown]
# # Video Capturing

# %%
cap = cv2.VideoCapture(0)
cap.set(3, 1280)
cap.set(4, 720)
# Out:
# True

# %% [markdown]
# # Loading Model Weights

# %%
model = YOLO("playingCards.pt")

# %% [markdown]
# # Defining Class Names

# %%
classNames = ['10C', '10D', '10H', '10S',
              '2C', '2D', '2H', '2S',
              '3C', '3D', '3H', '3S',
              '4C', '4D', '4H', '4S',
              '5C', '5D', '5H', '5S',
              '6C', '6D', '6H', '6S',
              '7C', '7D', '7H', '7S',
              '8C', '8D', '8H', '8S',
              '9C', '9D', '9H', '9S',
              'AC', 'AD', 'AH', 'AS',
              'JC', 'JD', 'JH', 'JS',
              'KC', 'KD', 'KH', 'KS',
              'QC', 'QD', 'QH', 'QS']

# %% [markdown]
# # Detections

# %%
while True:
    success, img = cap.read()
    results = model(img, stream=True)
    hand = []

    for r in results:
        boxes = r.boxes
        for box in boxes:
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
            w, h = x2 - x1, y2 - y1

            cvzone.cornerRect(img, (x1, y1, w, h))

            conf = math.ceil(box.conf[0] * 100) / 100

            cls = int(box.cls[0])

            cvzone.putTextRect(img, f'{classNames[cls]} {conf}', (max(0, x1), max(35, y1)), scale=1, thickness=1)
            
            if conf > 0.5:
                hand.append(classNames[cls])
    
    hand = list(set(hand))

    if len(hand) == 5:
        results = HelperFunction.findPokerHand(hand)
        cvzone.putTextRect(img, f'Your Hand: {results}', (300, 75), scale=3, thickness=5)

    cv2.imshow("Image", img)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        cap.release()
        cv2.destroyAllWindows()
        break
# Out:
# 0: 384x640 (no detections), 489.1ms
# Speed: 3.2ms preprocess, 489.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 450.6ms
# Speed: 2.9ms preprocess, 450.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 499.9ms
# Speed: 1.8ms preprocess, 499.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 426.2ms
# Speed: 3.9ms preprocess, 426.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 461.6ms
# Speed: 5.6ms preprocess, 461.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 365.8ms
# Speed: 5.6ms preprocess, 365.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 403.9ms
# Speed: 3.8ms preprocess, 403.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 475.8ms
# Speed: 1.7ms preprocess, 475.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 399.1ms
# Speed: 1.7ms preprocess, 399.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 473.7ms
# Speed: 6.2ms preprocess, 473.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 404.3ms
# Speed: 4.4ms preprocess, 404.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 425.7ms
# Speed: 2.1ms preprocess, 425.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 426.3ms
# Speed: 4.3ms preprocess, 426.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 392.3ms
# Speed: 3.0ms preprocess, 392.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 408.5ms
# Speed: 1.8ms preprocess, 408.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 406.4ms
# Speed: 4.8ms preprocess, 406.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 400.2ms
# Speed: 1.6ms preprocess, 400.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 480.6ms
# Speed: 1.6ms preprocess, 480.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 604.8ms
# Speed: 2.2ms preprocess, 604.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 465.7ms
# Speed: 1.6ms preprocess, 465.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 510.6ms
# Speed: 4.6ms preprocess, 510.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 362.3ms
# Speed: 3.8ms preprocess, 362.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 2C, 1 2S, 1 AH, 1 JD, 381.5ms
# Speed: 3.0ms preprocess, 381.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 2C, 1 2D, 1 2H, 2 2Ss, 1 6D, 480.8ms
# Speed: 3.4ms preprocess, 480.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 2C, 1 2D, 1 2H, 1 2S, 1 6D, 346.0ms
# Speed: 4.6ms preprocess, 346.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# ['2C', '2H', '2S', '6D', '2D'] Four of a Kind
#
# 0: 384x640 1 2C, 1 2D, 1 2H, 1 2S, 1 6D, 340.1ms
# Speed: 3.2ms preprocess, 340.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# ['2C', '2H', '2S', '6D', '2D'] Four of a Kind
#
# 0: 384x640 1 2C, 1 2D, 1 2H, 1 2S, 1 6D, 332.5ms
# Speed: 1.9ms preprocess, 332.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# ['2C', '2H', '2S', '6D', '2D'] Four of a Kind
#
# 0: 384x640 1 2C, 1 2D, 1 2H, 1 2S, 1 6D, 370.1ms
# Speed: 4.8ms preprocess, 370.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# ['2C', '2H', '2S', '6D', '2D'] Four of a Kind
#
# 0: 384x640 1 2C, 1 2D, 1 2H, 1 2S, 1 6D, 340.1ms
# Speed: 3.2ms preprocess, 340.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# ['2C', '2H', '2S', '6D', '2D'] Four of a Kind
#
# 0: 384x640 1 2C, 1 2D, 1 2H, 1 2S, 1 6D, 352.0ms
# Speed: 1.5ms preprocess, 352.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# ['2C', '2H', '2S', '6D', '2D'] Four of a Kind
#
# 0: 384x640 1 2C, 1 2D, 1 2H, 1 2S, 1 6D, 363.1ms
# Speed: 3.1ms preprocess, 363.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# ['2C', '2H', '2S', '6D', '2D'] Four of a Kind
#
# 0: 384x640 1 2C, 1 2D, 1 2H, 1 2S, 1 6D, 336.7ms
# Speed: 1.7ms preprocess, 336.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# ['2C', '2H', '2S', '6D', '2D'] Four of a Kind
#
# 0: 384x640 1 2C, 1 2D, 1 2H, 1 2S, 1 6D, 365.7ms
# Speed: 5.0ms preprocess, 365.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# ['2C', '2H', '2S', '6D', '2D'] Four of a Kind
#
# 0: 384x640 1 2C, 1 2D, 1 2H, 1 2S, 1 6D, 334.5ms
# Speed: 4.1ms preprocess, 334.5ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
# ['2C', '2H', '2S', '6D', '2D'] Four of a Kind
#
# 0: 384x640 1 2C, 1 2D, 1 2H, 1 2S, 1 6D, 353.4ms
# Speed: 3.1ms preprocess, 353.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# ['2C', '2H', '2S', '6D', '2D'] Four of a Kind
#
# 0: 384x640 1 2C, 1 2D, 1 2H, 1 2S, 1 6D, 360.2ms
# Speed: 1.9ms preprocess, 360.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# ['2C', '2H', '2S', '6D', '2D'] Four of a Kind
#
# 0: 384x640 1 2C, 1 2D, 1 2H, 1 2S, 1 6D, 340.2ms
# Speed: 3.0ms preprocess, 340.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# ['2C', '2H', '2S', '6D', '2D'] Four of a Kind
#
# 0: 384x640 (no detections), 367.3ms
# Speed: 24.7ms preprocess, 367.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 348.8ms
# Speed: 3.9ms preprocess, 348.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 338.0ms
# Speed: 3.1ms preprocess, 338.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 354.3ms
# Speed: 9.4ms preprocess, 354.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 344.1ms
# Speed: 3.7ms preprocess, 344.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 334.2ms
# Speed: 3.9ms preprocess, 334.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 353.9ms
# Speed: 1.7ms preprocess, 353.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 343.8ms
# Speed: 3.4ms preprocess, 343.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 348.1ms
# Speed: 3.4ms preprocess, 348.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 342.0ms
# Speed: 3.4ms preprocess, 342.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 362.0ms
# Speed: 3.8ms preprocess, 362.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 327.3ms
# Speed: 4.0ms preprocess, 327.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 346.2ms
# Speed: 5.1ms preprocess, 346.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 396.2ms
# Speed: 1.6ms preprocess, 396.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 409.0ms
# Speed: 5.0ms preprocess, 409.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 529.8ms
# Speed: 3.3ms preprocess, 529.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 535.2ms
# Speed: 4.2ms preprocess, 535.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 349.5ms
# Speed: 3.6ms preprocess, 349.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 364.8ms
# Speed: 3.4ms preprocess, 364.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 365.6ms
# Speed: 2.0ms preprocess, 365.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 492.8ms
# Speed: 6.1ms preprocess, 492.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 574.2ms
# Speed: 2.3ms preprocess, 574.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 479.6ms
# Speed: 1.8ms preprocess, 479.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 553.0ms
# Speed: 3.7ms preprocess, 553.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 541.5ms
# Speed: 1.7ms preprocess, 541.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 427.2ms
# Speed: 4.6ms preprocess, 427.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 446.2ms
# Speed: 3.4ms preprocess, 446.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 462.8ms
# Speed: 3.8ms preprocess, 462.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 538.5ms
# Speed: 4.0ms preprocess, 538.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 533.7ms
# Speed: 2.4ms preprocess, 533.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 546.7ms
# Speed: 2.3ms preprocess, 546.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 426.0ms
# Speed: 2.9ms preprocess, 426.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 490.7ms
# Speed: 4.6ms preprocess, 490.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 490.0ms
# Speed: 1.9ms preprocess, 490.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 488.8ms
# Speed: 5.5ms preprocess, 488.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 418.7ms
# Speed: 5.1ms preprocess, 418.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 413.2ms
# Speed: 3.1ms preprocess, 413.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 352.0ms
# Speed: 1.6ms preprocess, 352.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 354.9ms
# Speed: 4.6ms preprocess, 354.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 361.8ms
# Speed: 3.8ms preprocess, 361.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 469.3ms
# Speed: 4.9ms preprocess, 469.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 334.5ms
# Speed: 5.5ms preprocess, 334.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 351.2ms
# Speed: 2.9ms preprocess, 351.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 356.5ms
# Speed: 5.5ms preprocess, 356.5ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 348.4ms
# Speed: 3.6ms preprocess, 348.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
